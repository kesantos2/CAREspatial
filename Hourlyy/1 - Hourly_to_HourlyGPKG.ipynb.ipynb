# %%
# 11_Hourly_to_HourlyGPKG.ipynb
# Input: hourly CSV (Date, Time, location_name, latitude, longitude, pm25)
# Output: one GPKG per day with a single layer:
#   - hourly_points (all hourly rows for that date, with geometry)

# %%
import os
import pandas as pd
import geopandas as gpd

# -------- EDIT THESE --------
HOURLY_CSV = r"C:\Users\krish\Desktop\SpatialCARE\Hourly\pasig_hourly_corrected.csv"
OUT_HOURLY_GPKG_DIR = r"C:\Users\krish\Desktop\SpatialCARE\Hourly\HourlyGPKG"
os.makedirs(OUT_HOURLY_GPKG_DIR, exist_ok=True)
TIMEZONE = "Asia/Manila"
# ----------------------------

# Column names from your sample
DATE_COL     = "Date"
TIME_COL     = "Time"
STATION_COL  = "location_name"
LAT_COL      = "latitude"
LON_COL      = "longitude"
PM_COL       = "pm25"

# Read hourly CSV
df = pd.read_csv(HOURLY_CSV)

# Clean PM and time
df[PM_COL] = pd.to_numeric(df[PM_COL], errors="coerce").clip(lower=0, upper=500)
ts = pd.to_datetime(df[DATE_COL].astype(str) + " " + df[TIME_COL].astype(str), errors="coerce")

# Localize to Asia/Manila (treat as local)
if ts.dt.tz is None:
    ts = ts.dt.tz_localize(TIMEZONE)
else:
    ts = ts.dt.tz_convert(TIMEZONE)

df["ts_local"] = ts
df["date_key"] = df["ts_local"].dt.date
df["hour"] = df["ts_local"].dt.hour

# Remove rows with bad coords or times
df[LAT_COL] = pd.to_numeric(df[LAT_COL], errors="coerce")
df[LON_COL] = pd.to_numeric(df[LON_COL], errors="coerce")
df = df.dropna(subset=["ts_local", PM_COL, LAT_COL, LON_COL]).copy()

# Make sure station names are strings
df[STATION_COL] = df[STATION_COL].astype(str)

WGS84 = "EPSG:4326"
written = 0

for day, df_day in df.groupby("date_key", sort=True):
    # Hourly rows for this day
    hday = df_day[[STATION_COL, "ts_local", "hour", PM_COL, LAT_COL, LON_COL]].copy()
    hday["timestamp"] = hday["ts_local"].dt.strftime("%Y-%m-%d %H:%M:%S%z")

    gdf_hourly = gpd.GeoDataFrame(
        hday.drop(columns=[LAT_COL, LON_COL]),
        geometry=gpd.points_from_xy(hday[LON_COL], hday[LAT_COL]),
        crs=WGS84
    )
    gdf_hourly["date"] = pd.to_datetime(day).strftime("%Y-%m-%d")

    out = os.path.join(OUT_HOURLY_GPKG_DIR, f"hourly_{pd.to_datetime(day).strftime('%Y-%m-%d')}.gpkg")
    if os.path.exists(out):
        os.remove(out)

    gdf_hourly.to_file(out, layer="hourly_points", driver="GPKG")
    written += 1
    print(f"✓ Wrote {os.path.basename(out)} | hourly rows: {gdf_hourly.shape[0]}")

print(f"\nDone. Wrote {written} hourly GPKGs to:\n  {OUT_HOURLY_GPKG_DIR}")
# Out:
# ✓ Wrote hourly_2025-01-01.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-02.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-03.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-04.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-05.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-06.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-07.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-08.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-09.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-10.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-11.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-12.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-13.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-14.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-15.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-16.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-17.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-18.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-19.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-20.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-21.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-22.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-23.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-24.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-25.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-26.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-27.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-28.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-29.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-30.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-01-31.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-02-01.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-02-02.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-02-03.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-02-04.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-02-05.gpkg | hourly rows: 24
# ✓ Wrote hourly_2025-02-06.gpkg | hourly rows: 120
# ✓ Wrote hourly_2025-02-07.gpkg | hourly rows: 120
# ✓ Wrote hourly_2025-02-08.gpkg | hourly rows: 120
# ✓ Wrote hourly_2025-02-09.gpkg | hourly rows: 120
# ✓ Wrote hourly_2025-02-10.gpkg | hourly rows: 120
# ✓ Wrote hourly_2025-02-11.gpkg | hourly rows: 90
# ✓ Wrote hourly_2025-02-12.gpkg | hourly rows: 97
# ✓ Wrote hourly_2025-02-13.gpkg | hourly rows: 172
# ✓ Wrote hourly_2025-02-14.gpkg | hourly rows: 179
# ✓ Wrote hourly_2025-02-15.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-02-16.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-02-17.gpkg | hourly rows: 179
# ✓ Wrote hourly_2025-02-18.gpkg | hourly rows: 179
# ✓ Wrote hourly_2025-02-19.gpkg | hourly rows: 180
# ✓ Wrote hourly_2025-02-20.gpkg | hourly rows: 185
# ✓ Wrote hourly_2025-02-21.gpkg | hourly rows: 192
# ✓ Wrote hourly_2025-02-22.gpkg | hourly rows: 192
# ✓ Wrote hourly_2025-02-23.gpkg | hourly rows: 192
# ✓ Wrote hourly_2025-02-24.gpkg | hourly rows: 192
# ✓ Wrote hourly_2025-02-25.gpkg | hourly rows: 191
# ✓ Wrote hourly_2025-02-26.gpkg | hourly rows: 213
# ✓ Wrote hourly_2025-02-27.gpkg | hourly rows: 264
# ✓ Wrote hourly_2025-02-28.gpkg | hourly rows: 264
# ✓ Wrote hourly_2025-03-01.gpkg | hourly rows: 264
# ✓ Wrote hourly_2025-03-02.gpkg | hourly rows: 264
# ✓ Wrote hourly_2025-03-03.gpkg | hourly rows: 264
# ✓ Wrote hourly_2025-03-04.gpkg | hourly rows: 255
# ✓ Wrote hourly_2025-03-05.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-03-06.gpkg | hourly rows: 222
# ✓ Wrote hourly_2025-03-07.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-03-08.gpkg | hourly rows: 229
# ✓ Wrote hourly_2025-03-09.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-03-10.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-03-11.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-03-12.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-03-13.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-03-14.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-03-15.gpkg | hourly rows: 236
# ✓ Wrote hourly_2025-03-16.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-03-17.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-03-18.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-03-19.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-03-20.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-03-21.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-03-22.gpkg | hourly rows: 232
# ✓ Wrote hourly_2025-03-23.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-03-24.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-03-25.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-03-26.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-03-27.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-03-28.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-03-29.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-03-30.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-03-31.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-01.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-02.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-03.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-04.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-05.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-06.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-07.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-08.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-09.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-10.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-11.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-12.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-13.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-14.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-15.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-16.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-17.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-18.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-19.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-20.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-21.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-22.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-23.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-24.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-25.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-26.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-27.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-28.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-29.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-04-30.gpkg | hourly rows: 246
# ✓ Wrote hourly_2025-05-01.gpkg | hourly rows: 288
# ✓ Wrote hourly_2025-05-02.gpkg | hourly rows: 288
# ✓ Wrote hourly_2025-05-03.gpkg | hourly rows: 288
# ✓ Wrote hourly_2025-05-04.gpkg | hourly rows: 270
# ✓ Wrote hourly_2025-05-05.gpkg | hourly rows: 234
# ✓ Wrote hourly_2025-05-06.gpkg | hourly rows: 235
# ✓ Wrote hourly_2025-05-07.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-08.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-09.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-10.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-11.gpkg | hourly rows: 259
# ✓ Wrote hourly_2025-05-12.gpkg | hourly rows: 264
# ✓ Wrote hourly_2025-05-13.gpkg | hourly rows: 264
# ✓ Wrote hourly_2025-05-14.gpkg | hourly rows: 264
# ✓ Wrote hourly_2025-05-15.gpkg | hourly rows: 264
# ✓ Wrote hourly_2025-05-16.gpkg | hourly rows: 264
# ✓ Wrote hourly_2025-05-17.gpkg | hourly rows: 256
# ✓ Wrote hourly_2025-05-18.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-19.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-20.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-21.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-22.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-23.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-24.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-25.gpkg | hourly rows: 238
# ✓ Wrote hourly_2025-05-26.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-27.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-28.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-29.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-30.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-05-31.gpkg | hourly rows: 190
# ✓ Wrote hourly_2025-06-01.gpkg | hourly rows: 81
# ✓ Wrote hourly_2025-06-02.gpkg | hourly rows: 192
# ✓ Wrote hourly_2025-06-03.gpkg | hourly rows: 192
# ✓ Wrote hourly_2025-06-04.gpkg | hourly rows: 192
# ✓ Wrote hourly_2025-06-05.gpkg | hourly rows: 206
# ✓ Wrote hourly_2025-06-06.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-06-07.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-06-08.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-06-09.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-06-10.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-06-11.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-06-12.gpkg | hourly rows: 222
# ✓ Wrote hourly_2025-06-13.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-06-14.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-06-15.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-06-16.gpkg | hourly rows: 240
# ✓ Wrote hourly_2025-06-17.gpkg | hourly rows: 232
# ✓ Wrote hourly_2025-06-18.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-06-19.gpkg | hourly rows: 216
# ✓ Wrote hourly_2025-06-20.gpkg | hourly rows: 202
# ✓ Wrote hourly_2025-06-21.gpkg | hourly rows: 162
# ✓ Wrote hourly_2025-06-22.gpkg | hourly rows: 152
# ✓ Wrote hourly_2025-06-23.gpkg | hourly rows: 135
# ✓ Wrote hourly_2025-06-24.gpkg | hourly rows: 135
# ✓ Wrote hourly_2025-06-25.gpkg | hourly rows: 144
# ✓ Wrote hourly_2025-06-26.gpkg | hourly rows: 141
# ✓ Wrote hourly_2025-06-27.gpkg | hourly rows: 120
# ✓ Wrote hourly_2025-06-28.gpkg | hourly rows: 120
# ✓ Wrote hourly_2025-06-29.gpkg | hourly rows: 119
# ✓ Wrote hourly_2025-06-30.gpkg | hourly rows: 129
# ✓ Wrote hourly_2025-07-01.gpkg | hourly rows: 144
# ✓ Wrote hourly_2025-07-02.gpkg | hourly rows: 159
# ✓ Wrote hourly_2025-07-03.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-04.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-05.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-06.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-07.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-08.gpkg | hourly rows: 181
# ✓ Wrote hourly_2025-07-09.gpkg | hourly rows: 192
# ✓ Wrote hourly_2025-07-10.gpkg | hourly rows: 181
# ✓ Wrote hourly_2025-07-11.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-12.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-13.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-14.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-15.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-16.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-17.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-18.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-19.gpkg | hourly rows: 166
# ✓ Wrote hourly_2025-07-20.gpkg | hourly rows: 117
# ✓ Wrote hourly_2025-07-21.gpkg | hourly rows: 130
# ✓ Wrote hourly_2025-07-22.gpkg | hourly rows: 120
# ✓ Wrote hourly_2025-07-23.gpkg | hourly rows: 120
# ✓ Wrote hourly_2025-07-24.gpkg | hourly rows: 120
# ✓ Wrote hourly_2025-07-25.gpkg | hourly rows: 127
# ✓ Wrote hourly_2025-07-26.gpkg | hourly rows: 161
# ✓ Wrote hourly_2025-07-27.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-28.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-29.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-30.gpkg | hourly rows: 168
# ✓ Wrote hourly_2025-07-31.gpkg | hourly rows: 112
#
# Done. Wrote 212 hourly GPKGs to:
#   C:\Users\krish\Desktop\SpatialCARE\Hourly\HourlyGPKG
