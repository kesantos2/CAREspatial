# %%
import os, glob, csv, warnings
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib as mpl
import matplotlib.colors as mcolors
import matplotlib.patches as mpatches
from shapely.ops import unary_union
from fiona.env import Env
from pykrige.ok import OrdinaryKriging
from numpy.linalg import LinAlgError
from scipy.spatial import cKDTree

# -------- Paths
DATA_DIR   = r"C:\Users\krish\Desktop\SpatialCARE\DailyGPKG"
PASIG_SHP  = r"C:\Users\krish\Desktop\PhD Class\Shapefile\MM\Pasig\Pasig.shp"
OUT_F_DIR  = r"C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours"
OUT_CSV    = r"C:\Users\krish\Desktop\SpatialCARE\Outputs\exceedance_local_summary.csv"
os.makedirs(OUT_F_DIR, exist_ok=True)

# -------- Settings
WGS84, UTM51 = "+proj=longlat +datum=WGS84 +no_defs", "+proj=utm +zone=51 +datum=WGS84 +units=m +no_defs"
FIG_SIZE, FIG_DPI = (7,7), 150
GRID_RES_M = 100
VARIOGRAM_MODEL, RETRY_NUGGET = "spherical", 1e-3
COVERAGE_MAX_DIST_M = 3000

# Local guideline
BINS    = [0.0, 25.0, 35.0, 45.0, 55.0, 90.0, np.inf]
LABELS  = ["Good (0–25)","Fair (25.1–35)","Unhealthy (sens.) (35.1–45)",
           "Very unhealthy (45.1–55)","Acutely unhealthy (55.1–90)","Emergency (≥91)"]
COLORS  = ["#00E400","#FFFF00","#FF7E00","#FF0000","#8F3F97","#7E0023"]
CMAP_CAT = mpl.colors.ListedColormap(COLORS)
NORM_CAT = mpl.colors.BoundaryNorm(BINS, ncolors=len(COLORS), clip=False)

# Contours to label (pick a few to avoid clutter)
CONTOURS = [25, 35, 55, 90]

def pick_pm_col(cols):
    for c in cols:
        if str(c).lower() in ("pm25","pm_25","pm2_5","pm2.5"): return c
    return None

# Boundary & grid
with Env(SHAPE_RESTORE_SHX="YES"):
    pasig = gpd.read_file(PASIG_SHP)
if pasig.crs is None: pasig = pasig.set_crs(WGS84)
pasig_utm = pasig.to_crs(UTM51)
geom = unary_union(pasig_utm.geometry)
minx,miny,maxx,maxy = geom.bounds
xs = np.arange(minx, maxx+GRID_RES_M, GRID_RES_M)
ys = np.arange(miny, maxy+GRID_RES_M, GRID_RES_M)
grid_x, grid_y = np.meshgrid(xs, ys)

# CSV header
if not os.path.exists(OUT_CSV):
    with open(OUT_CSV, "w", newline="", encoding="utf-8") as f:
        csv.writer(f).writerow([
            "date","stations",
            "pct_gt25","pct_gt35","pct_gt55","pct_ge91",
            "pct_good","pct_fair","pct_unsens","pct_very","pct_acute","pct_emerg",
            "total_area_km2"
        ])

files = sorted(glob.glob(os.path.join(DATA_DIR, "date_2025-*.gpkg")))
if not files: raise SystemExit("No daily GPKG files found.")

for f in files:
    base = os.path.splitext(os.path.basename(f))[0]
    day  = base.replace("date_","")

    g = gpd.read_file(f)
    if g.crs is None: g = g.set_crs(WGS84)
    if ("geometry" not in g) or g.geometry.is_empty.all():
        lon = next((c for c in g.columns if str(c).lower() in ("longitude","lon","x")), None)
        lat = next((c for c in g.columns if str(c).lower() in ("latitude","lat","y")), None)
        if lon and lat:
            g = g.set_geometry(gpd.points_from_xy(g[lon], g[lat], crs=g.crs))
        else:
            print("Skip (no geometry):", base); continue

    pm_col = pick_pm_col(g.columns)
    if pm_col is None: print("Skip (no PM):", base); continue

    pts = g.to_crs(UTM51)[[pm_col,"geometry"]].copy()
    pts["x"]=pts.geometry.x; pts["y"]=pts.geometry.y
    pts = pts.groupby(["x","y"], as_index=False)[pm_col].mean()
    x = pts["x"].values; y = pts["y"].values; z = np.clip(pts[pm_col].astype(float).values, 0, None)
    if len(z)<3: print("Skip (n<3):", base); continue

    # Kriging
    try:
        OK = OrdinaryKriging(x,y,z, variogram_model=VARIOGRAM_MODEL,
                             enable_plotting=False, verbose=False, coordinates_type="euclidean")
        zg, zv = OK.execute("grid", xs, ys, backend="loop"); zg = np.array(zg)
    except LinAlgError:
        OK = OrdinaryKriging(x,y,z, variogram_model=VARIOGRAM_MODEL, nugget=RETRY_NUGGET,
                             enable_plotting=False, verbose=False, coordinates_type="euclidean")
        zg, zv = OK.execute("grid", xs, ys, backend="loop"); zg = np.array(zg)

    # Masks
    tree = cKDTree(np.c_[x,y]); dists,_ = tree.query(np.c_[grid_x.ravel(), grid_y.ravel()], k=1)
    cover = dists.reshape(grid_x.shape) <= COVERAGE_MAX_DIST_M
    centers = gpd.GeoSeries(gpd.points_from_xy(grid_x.ravel(), grid_y.ravel()), crs=UTM51)
    inside  = centers.within(geom).values.reshape(zg.shape)
    zmask = np.where(cover & inside, np.maximum(zg,0.0), np.nan)

    if not np.isfinite(zmask).any():
        print("Skip (no valid cells):", base); continue

    # Percent area by thresholds
    cell_area_km2 = (GRID_RES_M*GRID_RES_M)/1e6
    total_area_km2 = np.isfinite(zmask).sum()*cell_area_km2
    pct_gt25 = 100.0*(np.nan_to_num(zmask>25).sum()*cell_area_km2)/max(1e-9,total_area_km2)
    pct_gt35 = 100.0*(np.nan_to_num(zmask>35).sum()*cell_area_km2)/max(1e-9,total_area_km2)
    pct_gt55 = 100.0*(np.nan_to_num(zmask>55).sum()*cell_area_km2)/max(1e-9,total_area_km2)
    pct_ge91 = 100.0*(np.nan_to_num(zmask>=91).sum()*cell_area_km2)/max(1e-9,total_area_km2)

    # Percent by categories
    idx = np.digitize(zmask, BINS, right=True) - 1  # -1..5
    cats = [(idx==i).sum() for i in range(6)]
    pct_by_cat = [100.0*(c*cell_area_km2)/max(1e-9,total_area_km2) for c in cats]

    # Plot categorical with local contours
    cat_mask = np.ma.masked_where(~np.isfinite(zmask), idx)
    fig, ax = plt.subplots(figsize=FIG_SIZE, dpi=FIG_DPI)
    im = ax.imshow(cat_mask, extent=[xs[0], xs[-1], ys[0], ys[-1]],
                   origin="lower", cmap=CMAP_CAT, norm=NORM_CAT)
    pasig_utm.boundary.plot(ax=ax, color="black", linewidth=0.8)

    try:
        cs = ax.contour(grid_x, grid_y, zmask, levels=CONTOURS,
                        colors="black", linewidths=0.9, linestyles=["--","-","-","-"])
        ax.clabel(cs, fmt=lambda v: f"{int(v)} µg/m³", inline=True, fontsize=8)
    except Exception:
        pass

    subtitle = f"%>25: {pct_gt25:.1f} • %>35: {pct_gt35:.1f} • %>55: {pct_gt55:.1f} • %≥91: {pct_ge91:.1f} • Stations: {len(z)}"
    ax.set_title(f"PM₂.₅ (Local guideline) • {day}\n{subtitle}")
    ax.set_axis_off()
    patches = [mpatches.Patch(color=c, label=l) for c,l in zip(COLORS, LABELS)]
    ax.legend(handles=patches, loc="upper left", bbox_to_anchor=(1.01, 1.0), fontsize=9, frameon=True)

    out = os.path.join(OUT_F_DIR, f"{base}_kriged_localContours.png")
    plt.tight_layout(); plt.savefig(out, bbox_inches="tight"); plt.close(fig)
    print("Saved:", out)

    # CSV row
    with open(OUT_CSV, "a", newline="", encoding="utf-8") as fcsv:
        csv.writer(fcsv).writerow([
            day, len(z),
            pct_gt25, pct_gt35, pct_gt55, pct_ge91,
            *pct_by_cat, total_area_km2
        ])
# Out:
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-06_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-07_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-08_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-09_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-10_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-11_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-12_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-13_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-14_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-15_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-16_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-17_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-18_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-19_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-20_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-21_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-22_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-23_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-24_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-25_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-26_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-27_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-02-28_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-01_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-02_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-03_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-04_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-05_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-06_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-07_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-08_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-09_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-10_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-11_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-12_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-13_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-14_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-15_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-16_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-17_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-18_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-19_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-20_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-21_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-22_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-23_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-24_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-25_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-26_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-27_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-28_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-29_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-30_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-03-31_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-01_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-02_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-03_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-04_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-05_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-06_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-07_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-08_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-09_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-10_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-11_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-12_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-13_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-14_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-15_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-16_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-17_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-18_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-19_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-20_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-21_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-22_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-23_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-24_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-25_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-26_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-27_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-28_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-29_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-04-30_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-01_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-02_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-03_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-04_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-05_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-06_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-07_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-08_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-09_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-10_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-11_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-12_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-13_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-14_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-15_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-16_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-17_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-18_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-19_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-20_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-21_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-22_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-23_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-24_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-25_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-26_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-27_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-28_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-29_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-30_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-05-31_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-01_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-02_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-03_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-04_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-05_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-06_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-07_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-08_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-09_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-10_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-11_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-12_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-13_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-14_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-15_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-16_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-17_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-18_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-19_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-20_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-21_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-22_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-23_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-24_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-25_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-26_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-27_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-28_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-29_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-06-30_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-01_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-02_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-03_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-04_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-05_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-06_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-07_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-08_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-09_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-10_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-11_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-12_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-13_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-14_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-15_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-16_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-17_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-18_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-19_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-20_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-21_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-22_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-23_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-24_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-25_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-26_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-27_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-28_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-29_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-30_kriged_localContours.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\kriging_local_contours\date_2025-07-31_kriged_localContours.png
