# %%
import os, glob, warnings
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import matplotlib as mpl
from shapely.ops import unary_union
from fiona.env import Env
from pykrige.ok import OrdinaryKriging
from numpy.linalg import LinAlgError
from scipy.spatial import cKDTree

# ---- Paths
DATA_DIR  = r"C:\Users\krish\Desktop\SpatialCARE\DailyGPKG"
PASIG_SHP = r"C:\Users\krish\Desktop\PhD Class\Shapefile\MM\Pasig\Pasig.shp"
OUT_DIR   = r"C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty"
os.makedirs(OUT_DIR, exist_ok=True)

# ---- CRS, fig, grid, kriging
WGS84, UTM51 = "+proj=longlat +datum=WGS84 +no_defs", "+proj=utm +zone=51 +datum=WGS84 +units=m +no_defs"
FIG_SIZE, FIG_DPI = (7,7), 150
GRID_RES_M = 100
VARIOGRAM_MODEL, RETRY_NUGGET = "spherical", 1e-3
COVERAGE_MAX_DIST_M = 3000

CMAP_VAR = mpl.colormaps["Greys"]  # lighter = lower uncertainty, darker = higher

def pick_pm_col(cols):
    for c in cols:
        if str(c).lower() in ("pm25","pm_25","pm2_5","pm2.5"): return c
    return None

# ---- Boundary & grid
with Env(SHAPE_RESTORE_SHX="YES"):
    pasig = gpd.read_file(PASIG_SHP)
if pasig.crs is None: pasig = pasig.set_crs(WGS84)
pasig_utm = pasig.to_crs(UTM51)
geom = unary_union(pasig_utm.geometry)
minx,miny,maxx,maxy = geom.bounds

xs = np.arange(minx, maxx+GRID_RES_M, GRID_RES_M)
ys = np.arange(miny, maxy+GRID_RES_M, GRID_RES_M)
grid_x, grid_y = np.meshgrid(xs, ys)

# ---- Files
files = sorted(glob.glob(os.path.join(DATA_DIR, "date_2025-*.gpkg")))
if not files: raise SystemExit("No daily GPKGs found.")

for f in files:
    base = os.path.splitext(os.path.basename(f))[0]
    day  = base.replace("date_","")

    g = gpd.read_file(f)
    if g.crs is None: g = g.set_crs(WGS84)

    if ("geometry" not in g) or g.geometry.is_empty.all():
        lon = next((c for c in g.columns if str(c).lower() in ("longitude","lon","x")), None)
        lat = next((c for c in g.columns if str(c).lower() in ("latitude","lat","y")), None)
        if lon and lat:
            g = g.set_geometry(gpd.points_from_xy(g[lon], g[lat], crs=g.crs))
        else:
            print("Skip (no geometry):", base); continue

    pm_col = pick_pm_col(g.columns)
    if pm_col is None: print("Skip (no PM):", base); continue

    pts = g.to_crs(UTM51)[[pm_col,"geometry"]].copy()
    pts["x"]=pts.geometry.x; pts["y"]=pts.geometry.y
    pts = pts.groupby(["x","y"], as_index=False)[pm_col].mean()
    pts = gpd.GeoDataFrame(pts, geometry=gpd.points_from_xy(pts["x"], pts["y"], crs=UTM51))

    x = pts["x"].to_numpy(); y = pts["y"].to_numpy()
    z = np.clip(pts[pm_col].astype(float).to_numpy(), 0, None)
    if len(z) < 3: print("Skip (n<3):", base); continue

    try:
        OK = OrdinaryKriging(x,y,z, variogram_model=VARIOGRAM_MODEL, enable_plotting=False,
                             verbose=False, coordinates_type="euclidean")
        zg, zv = OK.execute("grid", xs, ys, backend="loop")
        zv = np.array(zv)
    except LinAlgError:
        OK = OrdinaryKriging(x,y,z, variogram_model=VARIOGRAM_MODEL, nugget=RETRY_NUGGET,
                             enable_plotting=False, verbose=False, coordinates_type="euclidean")
        zg, zv = OK.execute("grid", xs, ys, backend="loop")
        zv = np.array(zv)

    # Masks: coverage + inside boundary
    tree = cKDTree(np.c_[x,y]); dists,_ = tree.query(np.c_[grid_x.ravel(), grid_y.ravel()], k=1)
    cover = (dists.reshape(grid_x.shape) <= COVERAGE_MAX_DIST_M)
    centers = gpd.GeoSeries(gpd.points_from_xy(grid_x.ravel(), grid_y.ravel()), crs=UTM51)
    inside  = centers.within(geom).to_numpy().reshape(zv.shape)
    var_mask = np.where(cover & inside, np.maximum(zv, 0.0), np.nan)

    # Robust normalization (95th pct) so extremes don't dominate
    vmax = float(np.nanpercentile(var_mask, 95)) if np.isfinite(var_mask).any() else 1.0
    norm = mpl.colors.Normalize(vmin=0.0, vmax=max(1e-9, vmax))

    fig, ax = plt.subplots(figsize=FIG_SIZE, dpi=FIG_DPI)
    im = ax.imshow(var_mask, extent=[xs[0], xs[-1], ys[0], ys[-1]],
                   origin="lower", cmap=CMAP_VAR, norm=norm)
    pasig_utm.boundary.plot(ax=ax, color="black", linewidth=0.8)
    cb = plt.colorbar(im, ax=ax, shrink=0.8); cb.set_label("Uncertainty (kriging variance)")
    ax.set_title(f"Uncertainty Map — {day}\nDarker = higher uncertainty")
    ax.set_axis_off()

    out = os.path.join(OUT_DIR, f"{base}_uncertainty.png")
    plt.tight_layout(); plt.savefig(out, bbox_inches="tight"); plt.close(fig)
    print("Saved:", out)
# Out:
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-06_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-07_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-08_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-09_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-10_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-11_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-12_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-13_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-14_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-15_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-16_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-17_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-18_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-19_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-20_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-21_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-22_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-23_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-24_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-25_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-26_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-27_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-02-28_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-01_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-02_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-03_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-04_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-05_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-06_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-07_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-08_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-09_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-10_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-11_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-12_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-13_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-14_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-15_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-16_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-17_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-18_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-19_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-20_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-21_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-22_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-23_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-24_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-25_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-26_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-27_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-28_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-29_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-30_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-03-31_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-01_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-02_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-03_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-04_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-05_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-06_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-07_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-08_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-09_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-10_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-11_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-12_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-13_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-14_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-15_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-16_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-17_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-18_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-19_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-20_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-21_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-22_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-23_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-24_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-25_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-26_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-27_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-28_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-29_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-04-30_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-01_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-02_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-03_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-04_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-05_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-06_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-07_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-08_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-09_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-10_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-11_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-12_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-13_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-14_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-15_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-16_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-17_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-18_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-19_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-20_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-21_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-22_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-23_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-24_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-25_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-26_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-27_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-28_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-29_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-30_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-05-31_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-01_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-02_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-03_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-04_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-05_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-06_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-07_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-08_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-09_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-10_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-11_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-12_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-13_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-14_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-15_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-16_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-17_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-18_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-19_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-20_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-21_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-22_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-23_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-24_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-25_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-26_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-27_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-28_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-29_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-06-30_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-01_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-02_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-03_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-04_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-05_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-06_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-07_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-08_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-09_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-10_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-11_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-12_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-13_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-14_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-15_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-16_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-17_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-18_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-19_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-20_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-21_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-22_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-23_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-24_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-25_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-26_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-27_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-28_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-29_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-30_uncertainty.png
# Saved: C:\Users\krish\Desktop\SpatialCARE\Outputs\figures\uncertainty\date_2025-07-31_uncertainty.png
